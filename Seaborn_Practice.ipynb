# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\13abh\\Music'

# %%
mart = pd.read_excel('supermarket_sales.xlsx')
mart
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 0    692-92-5582      B  Mandalay        Member  Female
# 1    351-62-0822      B  Mandalay        Member  Female
# 2    529-56-3974      B  Mandalay        Member    Male
# 3    299-46-1805      B  Mandalay        Member  Female
# 4    319-50-3348      B  Mandalay        Normal  Female
# ..           ...    ...       ...           ...     ...
# 995  886-18-2897      A    Yangon        Normal  Female
# 996  745-74-0715      A    Yangon        Normal    Male
# 997  727-02-1313      A    Yangon        Member    Male
# 998  347-56-2442      A    Yangon        Normal    Male
# 999  849-09-3807      A    Yangon        Member  Female
#
#                Product line  Unit price  Quantity  Tax 5%    Total  \
# 0        Food_and_beverages       54.84         3   8.226  172.746
# 1       Fashion_accessories       14.48         4   2.896   60.816
# 2    Electronic_accessories       25.51         4   5.102  107.142
# ...

# %%
print(mart.shape)
print(mart.columns)
print(mart.head)
# Out:
# (1000, 17)
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')
# <bound method NDFrame.head of       Invoice ID Branch      City Customer type  Gender  \
# 0    692-92-5582      B  Mandalay        Member  Female
# 1    351-62-0822      B  Mandalay        Member  Female
# 2    529-56-3974      B  Mandalay        Member    Male
# 3    299-46-1805      B  Mandalay        Member  Female
# 4    319-50-3348      B  Mandalay        Normal  Female
# ..           ...    ...       ...           ...     ...
# 995  886-18-2897      A    Yangon        Normal  Female
# 996  745-74-0715      A    Yangon        Normal    Male
# 997  727-02-1313      A    Yangon        Member    Male
# 998  347-56-2442      A    Yangon        Normal    Male
# ...

# %%
sns.set_theme(style="darkgrid")
sns.countplot(x='Gender', data =mart,palette="spring") #palette="rainbow"
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(color='black',x="Customer type", data=mart,facecolor=(0, 0, 0, 0),linewidth=5,edgecolor=sns.color_palette("dark", 3))
# Out:
# <AxesSubplot:xlabel='Customer type', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', data=mart)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %%
#plotting in y axis
plt.figure(figsize=(5,5))
sns.countplot(y='Product line', data=mart)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Product line'>

# %%
#find the comparison between male and felame for each product.
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', data=mart, hue='Gender')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 #find the comparison between male and felame for each product.
# ----> 2 plt.figure(figsize=(15,5))
#       3 sns.countplot(x='Tenure(Months)', data=mart, hue='Gender')
#
# NameError: name 'plt' is not defined

# %%
#use different color palette
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', data=mart, hue='Gender', palette='PuBuGn') # pick a random palette to see the error message
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %%
#change facecoloe, line width, edge color
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', data = mart,
              facecolor= (0,0,0,0), linewidth =5, edgecolor=sns.color_palette('dark',6))
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %% [markdown]
# # barplot

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic= sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',hue='Gender', data = mart, order =['Electronic_accessories', 'Fashion_accessories',
       'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
       'Sports_and_travel'], hue_order=['Male','Female'])
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
x=mart['Product line'].sort_values()
x.unique()
# Out:
# array(['Electronic_accessories', 'Fashion_accessories',
#        'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
#        'Sports_and_travel'], dtype=object)

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',hue='Gender', data = mart, order =['Electronic_accessories', 'Fashion_accessories',
       'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
       'Sports_and_travel'], hue_order=['Male','Female'],capsize=0.2) #or ci=None : for removing the error bar
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='Product line',y='Total',hue='Gender', data = mart, order =['Electronic_accessories', 'Fashion_accessories',
       'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
       'Sports_and_travel'], hue_order=['Male','Female'],color='green',ci=None)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',hue='Gender', data = mart, order =['Electronic_accessories', 'Fashion_accessories',
       'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
       'Sports_and_travel'], hue_order=['Male','Female'],capsize=0.2, estimator=np.mean) #or estimator=sum
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %% [markdown]
#         # Boxplot

# %%
sns.boxplot(y='Total', data=mart, width =0.2) #total- a numerical variable
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
#boxplot on 1 numerical and 2 categorical variable
sns.boxplot(x='Payment',y='Total',hue = 'Gender', data=mart, width =0.5)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
#adding the mean market
plt.figure(figsize=(15,8))
sns.boxplot(x='Payment',y='Total',hue = 'Gender', data=mart, width =0.5, showmeans=True,meanprops={"marker" : "o"
                                                                                                  ,"markerfacecolor":"white"
                                                                                                  ,"markersize":"8"
                                                                                                  ,"markeredgecolor":"black"})
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
#adding the mean market

sns.boxplot(x='Payment',y='Total',hue = 'Gender', data=mart, width =0.5, showmeans=True,meanprops={"marker" : "o"
                                                                                                  ,"markerfacecolor":"white"
                                                                                                  ,"markersize":"8"
                                                                                                  ,"markeredgecolor":"black"}
           ,palette='CMRmap'
           ,linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
#creating box for each numeric values
plt.figure(figsize=(15,8))
sns.boxplot(data=mart)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # violinplot

# %%
#2 categorical value in 1 coilin plot
sns.violinplot(x='Payment', y='Total', hue='Gender', data = mart, split=True)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
#adding quartile and bandwith and cutting outliers
sns.violinplot(x='Payment', y='Total', hue='Gender', data = mart, split=True, inner='quartile', bw=.2, cut =0)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %% [markdown]
# # stripplot

# %%
sns.stripplot(data=mart, y='Total',x='Payment',hue='Gender', jitter=1, linewidth = 0.6)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
#creating separate strip for male and female
sns.stripplot(data=mart, y='Total',x='Payment',hue='Gender', jitter=.2, linewidth = 0.6,dodge=True)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
#Strip+violin
sns.stripplot(data=mart, y='Total',x='Payment', jitter=.2, linewidth = 0.6)#hue='Gender'
sns.violinplot(data=mart, y='Total',x='Payment',color='white')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
#Strip+box
sns.stripplot(data=mart, y='Total',x='Payment', jitter=.2, linewidth = 0.6, color='white')#hue='Gender'
sns.boxplot(data=mart, y='Total',x='Payment',color='grey')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %% [markdown]
# # swarmplot
# to present each datapoint on the plot

# %%
sns.swarmplot(data=mart,y='Total',color='green', hue='Gender',marker='*',edgecolor='red')
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.swarmplot(data=mart,y='Total',x='Payment',hue='Gender',split=True,color='Green')
# Out:
# C:\Users\13abh\anaconda3\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# C:\Users\13abh\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\13abh\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\13abh\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
plt.figure(figsize=(15,8))
sns.swarmplot(data=mart,y='Total',x='Payment',color='red',marker='*')
sns.violinplot(data=mart, y='Total',x='Payment',color='green',width=1)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
#CATPLOT
sns.catplot(data=mart,x='Payment',y='Total',col='Gender',kind='violin', row='Customer type')

# %% [markdown]
# # Distribution plot

# %%
import statistics as sts

# %%
pd.set_option('display.max_rows',None)
mart=mart[['Gender','Payment','Unit price','Quantity','Total','gross income']]
mart.head(10)
# Out:
#    Gender      Payment  Unit price  Quantity     Total  gross income
# 0  Female  Credit card       54.84         3  172.7460        8.2260
# 1  Female      Ewallet       14.48         4   60.8160        2.8960
# 2    Male         Cash       25.51         4  107.1420        5.1020
# 3  Female         Cash       93.72         6  590.4360       28.1160
# 4  Female      Ewallet       40.30         2   84.6300        4.0300
# 5    Male      Ewallet       87.98         3  277.1370       13.1970
# 6    Male  Credit card       33.20         2   69.7200        3.3200
# 7    Male         Cash       33.52         1   35.1960        1.6760
# 8  Female         Cash       88.36         5  463.8900       22.0900
# 9    Male  Credit card       94.13         5  494.1825       23.5325

# %%
sns.histplot(data=mart,x='Total',binwidth =100)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=mart,x='Total',bins=np.arange(0,1100,50))
plt.xticks(np.arange(0,1100,50))
# Out:
# ([<matplotlib.axis.XTick at 0x1ffef30f220>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#Combine with KDE
sns.histplot(data=mart,x='Total',binwidth =100,kde=True)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
#Categorical value
sns.histplot(data=mart,x='Total',hue='Payment',kde=True,multiple='stack')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data=mart,x='Total',element='step',fill=False)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data=mart,x='Total',hue='Payment',element='poly',fill=False)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
#Cspace between each bar
sns.histplot(data=mart,x='Total',hue='Payment',multiple='stack',shrink=0.8)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data=mart,x='Total',y='gross income')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='gross income'>

# %%
sns.histplot(data=mart,x='Total',stat='percent')#stat=''
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Percent'>

# %% [markdown]
# # KDE Plot
# Kernal Density Estimation

# %%
sns.kdeplot(data=mart,x='Total', color='black',bw_adjust=0.2)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
sns.kdeplot(data=mart,x='Total', hue='Payment')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
sns.kdeplot(data=mart,x='Total', hue='Payment',multiple='stack')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
sns.kdeplot(data=mart,x='Total',log_scale=True,hue='Payment'
            , linewidth=0.8,multiple='stack',palette='Dark2', alpha=0.4)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
sns.kdeplot(data=mart,x='Unit price',y='gross income',hue='Gender', fill= True,levels=5, thresh=0.2)#fill='False'
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='gross income'>

# %% [markdown]
# # rugplot

# %%
plt.figure(figsize=(15,5))
sns.rugplot(data=mart,x='Unit price', y='gross income',  hue='Gender', height =0.05)
sns.kdeplot(data=mart,x='Unit price', y='gross income',  hue='Gender',  fill=True)
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='gross income'>

# %%
plt.figure(figsize=(15,5))
sns.rugplot(data=mart,x='Unit price', y='gross income',  hue='Gender', height =0.05)
sns.scatterplot(data=mart,x='Unit price', y='gross income',  hue='Gender')
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='gross income'>

# %% [markdown]
# # ECDF Plot
# Emperical cumulative Distribution function

# %%
sns.ecdfplot(data=mart, x='gross income', hue='Gender', stat ='count')
# Out:
# <AxesSubplot:xlabel='gross income', ylabel='Count'>

# %% [markdown]
# # Distplot
# Distribution plot

# %%
plt.figure(figsize=(1,1))
sns.displot(data=mart,x='Total',hue='Payment',multiple='stack',kde=True,rug=True,rug_kws={'height':0.05})

# %%
#different graphs for male and Female
plt.figure(figsize=(1,1))
sns.displot(data=mart,x='Total',hue='Payment',multiple='stack',
            kde=True,rug=True,rug_kws={'height':0.05}
           , col='Gender')

# %%
#different graphs for male and Female adn multiple branch
sns.displot(data=mart,x='Total',hue='Payment',multiple='stack',
            kde=True,rug=True,rug_kws={'height':0.05}
           , col='Branch', row='Gender')#interchange branch and gender in row and col

# %%
#different graphs for male and Female adn multiple branch
sns.displot(data=mart,x='Total',kind='ecdf',hue='Payment'
           , col='Branch', row='Gender')#interchange branch and gender in row and col

# %% [markdown]
# # Joint plot
# 1 scatter and 2 marginal distribution plot

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.figure(figsize=(5,1))
sns.jointplot(data = iris, x='sepal_length',y='petal_length')#default=Scatter plot

# %%
plt.figure(figsize=(.5,1))
sns.jointplot(data = iris, x='sepal_length',y='petal_length'
              ,kind='reg',color='green')#or kind=kde,scatter,hex

# %%
sns.jointplot(data = iris, x='sepal_length',y='petal_length'
              ,hue='species')#or kind=kde,scatter,hex

# %%
#formatting the entire plot
sns.jointplot(data = iris, x='sepal_length',y='petal_length',hue='species'
              ,palette='gnuplot2_r',color='black')

# %%
#formatting the individual plots/species
sns.jointplot(data = iris, x='sepal_length',y='petal_length',hue='species'
              ,joint_kws=dict(marker='+',color='black')
              ,marginal_kws=dict(color='green'))
              #,palette='gnuplot2_r',color='black')

# %%
#height ratio and space
sns.jointplot(data = iris, x='sepal_length',y='petal_length', height=5,ratio=3,space=1,marginal_ticks=True)

# %%
#KDE+ROG+JOINT
l=sns.jointplot(data = iris, x='sepal_length',y='petal_length',joint_kws=dict(color='black'))#color='black')
l.plot_joint(sns.kdeplot)
l.plot_joint(sns.rugplot, height=0.1,color='black')

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(data=iris,diag_kind='kde', hue='species')#or Kind=Hist

# %%
sns.pairplot(data=iris,kind='reg', hue='species')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#pairplot for specific variables
sns.pairplot(data=iris, hue='species',x_vars=['sepal_width','petal_length','petal_width'],y_vars=['sepal_length','sepal_width'])

# %%
sns.pairplot(data=iris,kind='reg', hue='species',corner=True)

# %%
sns.pairplot(data=iris,diag_kws=dict(color='black',kde=True),plot_kws=dict(palette='gnuplot2_r') )

# %%
l=sns.pairplot(data=iris,plot_kws=dict(color='green'))
l.map_upper(sns.kdeplot,color='black')
#OR
l.map_lower(sns.kdeplot, color='grey')

# %% [markdown]
# # Relational
# Scatterplot,Lineplot,relplot

# %%
train=pd.read_excel("mart_train.xlsx")
train.head()
# Out:
#   Item_ID     Item_W              Item_Type    Item_MRP Outlet_ID  \
# 0   FDN27   9.437510            Snack Foods  195.313244    OUT046
# 1   FDW35   9.033762  Fruits and Vegetables   36.371449    OUT035
# 2   FDS28  20.884849           Frozen Foods   70.318167    OUT013
# 3   FDC09  19.976300            Snack Foods  121.723264    OUT018
# 4   FDX04  10.824812            Snack Foods  264.673302    OUT035
#
#    Outlet_Year Outlet_Size Outlet_Location_Type        Sales  Tier
# 0         1997       Small               Tier 1   897.085562     1
# 1         2003       Small               Tier 2  1639.303513     2
# 2         2008       Small               Tier 1  2664.773737     1
# 3         2009      Medium               Tier 3   440.859593     3
# 4         2004       Small               Tier 1    29.807098     1

# %%
sns.scatterplot(data=train,x='Item_MRP',y='Sales',style='Outlet_Size',hue='Outlet_Size')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Sales'>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=train,x='Item_MRP',y='Sales',style='Outlet_Size'
                ,hue='Outlet_Size',palette='Paired',size='Tier',sizes=(20,200),legend='full'
                ,markers={"High":"^","Small":"v","Medium":"o"})
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Sales'>

# %% [markdown]
# # Lineplot
# How does the value of a variable chamges over time

# %%
sns.lineplot(data=train,x='Outlet_Year',y='Sales',estimator=None,ci=None)#ci is confidence interval
# Out:
# <AxesSubplot:xlabel='Outlet_Year', ylabel='Sales'>

# %%
sns.lineplot(data=train,x='Outlet_Year',y='Sales',n_boot=100)#n_boot is no. of bootstrap;ci='sd')#sd=95%
# Out:
# <AxesSubplot:xlabel='Outlet_Year', ylabel='Sales'>

# %%
sns.lineplot(data=train,x='Outlet_Year',y='Sales',hue='Outlet_Size',palette=['red','green','blue'])
# Out:
# <AxesSubplot:xlabel='Outlet_Year', ylabel='Sales'>

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=train,x='Outlet_Year',y='Sales',style='Tier'
             ,hue='Outlet_Size',markers=True,sizes=(.5,5),ci=None)
# Out:
# <AxesSubplot:xlabel='Outlet_Year', ylabel='Sales'>

# %% [markdown]
# # Relation Plot

# %%
sns.relplot(data=train,x='Outlet_Year',y='Sales',s=100,hue='Outlet_Size'#,kind='line',ci=None)
            ,col='Outlet_Size'
            ,row='Tier')#,col_wrap=4)#row='tier'

# %% [markdown]
# # Regression Plot
# #finds best linear regression line to predict y value with changing X value

# %%
sns.regplot(data=train, x='Sales',y='Outlet_Size',n_boot=500#error due to numerical variable
                ,line_kws=dict(color='red',linestyle='--')
                ,scatter_kws=dict(color='red',alpha=0.5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 sns.regplot(data=train, x='Sales',y='Outlet_Size',n_boot=500#error due to numerical variable
#       2                 ,line_kws=dict(color='red',linestyle='--')
#       3                 ,scatter_kws=dict(color='red',alpha=0.5))
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # HeatMap

# %%
train.head()
# Out:
#   Item_ID     Item_W              Item_Type    Item_MRP Outlet_ID  \
# 0   FDN27   9.437510            Snack Foods  195.313244    OUT046
# 1   FDW35   9.033762  Fruits and Vegetables   36.371449    OUT035
# 2   FDS28  20.884849           Frozen Foods   70.318167    OUT013
# 3   FDC09  19.976300            Snack Foods  121.723264    OUT018
# 4   FDX04  10.824812            Snack Foods  264.673302    OUT035
#
#    Outlet_Year Outlet_Size Outlet_Location_Type        Sales  Tier
# 0         1997       Small               Tier 1   897.085562     1
# 1         2003       Small               Tier 2  1639.303513     2
# 2         2008       Small               Tier 1  2664.773737     1
# 3         2009      Medium               Tier 3   440.859593     3
# 4         2004       Small               Tier 1    29.807098     1

# %%
trainpiv=train.pivot_table(index='Outlet_Year',columns='Outlet_Size',values='Sales')
trainpiv
# Out:
# Outlet_Size         High       Medium        Small
# Outlet_Year
# 1987         2017.995778  1856.803961          NaN
# 1988         3651.266895          NaN   857.786220
# 1996                 NaN          NaN  1667.377374
# 1997         1556.877108          NaN  1822.922785
# 1998                 NaN          NaN  1672.015000
# 1999                 NaN          NaN  3663.856641
# 2003                 NaN          NaN  1639.303513
# 2004                 NaN  1549.733966  1533.338409
# 2008                 NaN  1347.352085  2880.060279
# 2009          881.035925  1908.697008  1593.659099

# %%
sns.set_style('dark')
plt.figure(figsize=(5,5))
sns.heatmap(trainpiv,annot=True,fmt='.0f',linecolor='black',linewidths=0.5,cmap='mako_r'
            ,annot_kws=dict(size=15,color='white',weight='bold'))
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Outlet_Year'>

# %%
#Correlation
sns.heatmap(train.corr(),annot=True, vmin=-1,vmax=1,center=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # ClusterMap
#
# plot matrix dataset as a hierarchically-clustered Heatmap

# %%
trainpiv.mean()
# Out:
# Outlet_Size
# High      2026.793927
# Medium    1665.646755
# Small     1925.591035
# dtype: float64

# %%
#sns.set_style('dark')
#plt.figure(figsize=(5,5))
sns.clustermap(trainpiv,row_cluster=False,annot=True,fmt='.0f',standard_scale=1,linewidth=0.5)

# %% [markdown]
# # FacetGrid Plot
# helps to create individual plot for each of the variable

# %%
train.head()
# Out:
#   Item_ID     Item_W              Item_Type    Item_MRP Outlet_ID  \
# 0   FDN27   9.437510            Snack Foods  195.313244    OUT046
# 1   FDW35   9.033762  Fruits and Vegetables   36.371449    OUT035
# 2   FDS28  20.884849           Frozen Foods   70.318167    OUT013
# 3   FDC09  19.976300            Snack Foods  121.723264    OUT018
# 4   FDX04  10.824812            Snack Foods  264.673302    OUT035
#
#    Outlet_Year Outlet_Size Outlet_Location_Type        Sales  Tier
# 0         1997       Small               Tier 1   897.085562     1
# 1         2003       Small               Tier 2  1639.303513     2
# 2         2008       Small               Tier 1  2664.773737     1
# 3         2009      Medium               Tier 3   440.859593     3
# 4         2004       Small               Tier 1    29.807098     1

# %%
print(train.Outlet_Size.unique())#Outlet_Location_Type
print(train.Outlet_Location_Type.unique())
# Out:
# ['Small' 'Medium' 'High']
# ['Tier 1' 'Tier 2' 'Tier 3']

# %%
x=sns.FacetGrid(data=train,col='')
x.map_dataframe(sns.lineplot,x='Outlet_Year',y='Sales',ci=None
               ,hue ='Outlet_Location_Type'
               ,alpha=0.5
               ,marker='+')#or HistPlot or scatterplot

# %%
x=sns.FacetGrid(data=train,col='Outlet_Size',row='Outlet_Location_Type',sharey=False,ylim=(0,1000))
x.map_dataframe(sns.histplot,x='Sales')
x.set_axis_labels('Sales','Count')
x.set_titles(col_templates='{col_name} Size',row_templates='{row_name} Type')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [249], in <cell line: 4>()
#       2 x.map_dataframe(sns.histplot,x='Sales')
#       3 x.set_axis_labels('Sales','Count')
# ----> 4 x.set_titles(col_templates='{col_name}',row_templates='{row_name}')
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:975, in FacetGrid.set_titles(self, template, row_template, col_template, **kwargs)
#     973             args.update(dict(row_name=row_name, col_name=col_name))
#     974             title = template.format(**args)
# --> 975             self.axes[i, j].set_title(title, **kwargs)
#     976 elif self.row_names is not None and len(self.row_names):
#     977     for i, row_name in enumerate(self.row_names):
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:169, in Axes.set_title(self, label, fontdict, loc, pad, y, **kwargs)
# ...
